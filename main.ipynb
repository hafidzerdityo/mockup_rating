# %%
from faker import Faker
fake = Faker()

# %%
import pandas as pd
from datetime import datetime

gas = 364
tgl  = pd.date_range(
    start=pd.Timestamp('2022-12-31') - pd.offsets.Day(gas),
    freq='D', periods=gas)
tgl
# Out:
# DatetimeIndex(['2022-01-01', '2022-01-02', '2022-01-03', '2022-01-04',
#                '2022-01-05', '2022-01-06', '2022-01-07', '2022-01-08',
#                '2022-01-09', '2022-01-10',
#                ...
#                '2022-12-21', '2022-12-22', '2022-12-23', '2022-12-24',
#                '2022-12-25', '2022-12-26', '2022-12-27', '2022-12-28',
#                '2022-12-29', '2022-12-30'],
#               dtype='datetime64[ns]', length=364, freq='D')

# %%
kategori = {
    1: ['paket rusak', 'salah alamat', 'lama'],
    2: ['kurir jutek', 'tidak komunikatif'],
    3: ['nothing special', 'kecepatan pengiriman biasa aja'],
    4: ['lumayan cepat', 'lumayan ramah', 'waktu normal'],
    5: ['pengiriman cepat', 'kurir ramah', 'tepat waktu', 'barang aman']
}

# %%
import pymongo
import pandas as pd

connection_string = "mongodb://localhost:27017"  # local

# mongo db cloud
# connection_string = f'mongodb+srv://hafidz_erdityo:lelegoreng@cluster0.uorwk7c.mongodb.net/?retryWrites=true&w=majority'

client = pymongo.MongoClient(connection_string)

# %%
get_data_wilayah = list(client['wilayah']['provinsi'].find({}))
get_data_wilayah = pd.DataFrame(get_data_wilayah)

# %%
get_data_wilayah
# Out:
#                          _id                       Provinsi  Kode wilayah[4]  \
# 0   638819156ed883f73c74efd6                           Aceh               11
# 1   638819156ed883f73c74efd7                  Sumatra Utara               12
# 2   638819156ed883f73c74efd8                  Sumatra Barat               13
# 3   638819156ed883f73c74efd9                           Riau               14
# 4   638819156ed883f73c74efda                          Jambi               15
# 5   638819156ed883f73c74efdb                Sumatra Selatan               16
# 6   638819156ed883f73c74efdc                       Bengkulu               17
# 7   638819156ed883f73c74efdd                        Lampung               18
# 8   638819156ed883f73c74efde      Kepulauan Bangka Belitung               19
# 9   638819156ed883f73c74efdf                 Kepulauan Riau               21
# 10  638819156ed883f73c74efe0  Daerah Khusus Ibukota Jakarta               31
# ...

# %%
big_str = ''

for i in get_data_wilayah['Provinsi'].to_list():
    big_str += i + '\n'

# %%
with open('data_provinsi.txt', 'w') as f:
    f.write(big_str)

# %%
with open('data_provinsi.txt') as f:
    data_provinsi = f.read()
data_provinsi = data_provinsi.split('\n')
data_provinsi[:3]
# Out:
# ['Aceh', 'Sumatra Utara', 'Sumatra Barat']

# %%
daftar_nama = []

for _ in range(50):
    daftar_nama.append(fake.name())
daftar_nama[:3]
# Out:
# ['Johnny Barry', 'Carol Chavez', 'Victoria Miller']

# %%
import random

# %%
kantor = [
    'Kantor A',
    'Kantor B',
    'Kantor C',
    'Kantor D',
    'Kantor E'
]

# %%
data = []


cnt = 0
for _ in range(100000):
    random_tgl = random.choice(tgl)
    each_data = {}
    each_data['id'] = cnt
    each_data['nama'] = random.choice(daftar_nama)
    each_data['tanggal'] = random_tgl
    each_data['rating'] = random.choice(range(1,6))
    each_data['kategori'] = random.choice(kategori.get(each_data['rating']))
    each_data['wilayah'] = random.choice(data_provinsi)
    each_data['kantor'] = random.choice(kantor)
    data.append(each_data)
    cnt += 1

# %%
import pandas as pd

x = pd.DataFrame(data)
x
# Out:
#           id              nama    tanggal  rating           kategori  \
# 0          0         Joe Lewis 2022-04-11       3    nothing special
# 1          1    Benjamin Davis 2022-06-19       3    nothing special
# 2          2    Tyrone Coleman 2022-05-21       1        paket rusak
# 3          3       Craig Brown 2022-06-22       5        tepat waktu
# 4          4  Dana Blankenship 2022-02-21       2  tidak komunikatif
# ...      ...               ...        ...     ...                ...
# 99995  99995      Ryan Johnson 2022-01-16       2  tidak komunikatif
# 99996  99996    Benjamin Davis 2022-05-28       4       waktu normal
# 99997  99997    Laura Lawrence 2022-03-16       1               lama
# 99998  99998      Carol Chavez 2022-06-04       4      lumayan ramah
# 99999  99999  William Martinez 2022-07-30       5        kurir ramah
#
#                  wilayah    kantor
# 0          Sumatra Utara  Kantor B
# 1                  Papua  Kantor A
# ...

# %%
x.to_csv('dummy.csv')
